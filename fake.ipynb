# %%
#模拟受欢迎程度
# {
#     "genre_name":"Adventure",
#     "people_num":4
# }
import random

random_integer = random.randint(2, 10)

import pandas as pd

df_genres=pd.read_csv('./load/genres.csv',index_col=0)
genre_list=df_genres['genre_name'].values

popularity_fake_list=[]
for i in range(1000):
    popularity_fake_list.append([random.choice(genre_list),random.randint(2,10)])

pd.DataFrame(popularity_fake_list,columns=['genre_name','people_num']).to_csv('./fake/popularity_fake.csv')

# %%
#模拟按合作次数查

{
    "cooperateLeftType": 0,
    "cooperateRightType": 0,
    "minCooperationTimes": 14,
    "cooperateLeftName":"William Shatner"
}

actors_list=pd.read_csv('./load/actors.csv',index_col=0)['actor_name'].values
directors_list=pd.read_csv('./load/directors.csv',index_col=0)['director_name'].values
cooperate_fake_list=[]
for i in range(1000):
    left_index=random.randint(0,1)
    right_index=random.randint(0,1)
    single_cooperate=[]
    single_cooperate.append(left_index)
    single_cooperate.append(right_index)
    single_cooperate.append(random.randint(1,100))
    if random.randint(0,6)==1:
        single_cooperate.append("null")
    else:
        if left_index==0:
            single_cooperate.append(random.choice(actors_list))
        else:
            single_cooperate.append(random.choice(directors_list))

    cooperate_fake_list.append(single_cooperate)

pd.DataFrame(cooperate_fake_list,columns=['cooperateLeftType','cooperateRightType','minCooperationTimes','cooperateLeftName']).to_csv('./fake/cooperate_fake.csv')

# %%
title_list=pd.read_csv('./load/movies.csv',index_col=0)['title'].values
format_list=pd.read_csv('./load/formats.csv',index_col=0)['format_name'].values
movie_fake_list=[]

for i in range(1000):
    single_movie=[]
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(1950,2023))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(1,12))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(1,31))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(1,4))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(1,7))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.choice(title_list))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.choice(directors_list))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.choice(actors_list))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.choice(actors_list))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.choice(genre_list))

    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.choice(format_list))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.uniform(0,3.5))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.uniform(3.5,5))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(0,1))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(60,100))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(100,200))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(0,20))
    if random.randint(0,5)==1:
        single_movie.append("null")
    else:
        single_movie.append(random.randint(20,300))
    movie_fake_list.append(single_movie)

pd.DataFrame(movie_fake_list,columns=['year','month','day','season','weekday','title','directorName','starActorName','supportActorName','genreName','formatName','minScore','maxScore','isPositive','minRunTime','maxRunTime','minCommentNum','maxCommentNum']).to_csv('./fake/movie_fake.csv')
